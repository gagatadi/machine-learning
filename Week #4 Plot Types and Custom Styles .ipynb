# %% [markdown]
# <a href="https://colab.research.google.com/github/gagatadi/machine-learning/blob/main/Week%20%234%20Plot%20Types%20and%20Custom%20Styles%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa_filepath = "/content/drive/MyDrive/machine-learning/fifa.csv"
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %%
# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=fifa_data)

# %%
# Change the style of the figure to the "dark" theme
sns.set_style("dark")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=fifa_data)
